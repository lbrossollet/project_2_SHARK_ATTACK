# %%
import pandas as pd
import numpy as np

df = pd.read_excel("GSAF5.xls")
sys.path.append('/work/test/')
from sharkfunctions_2 import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 5
#       2 import numpy as np
#       4 df = pd.read_excel("GSAF5.xls")
# ----> 5 sys.path.append('/work/test/')
#       6 from sharkfunctions_2 import *
#
# NameError: name 'sys' is not defined

# %%
url = "GSAF5.xls"

# %%
df_sharks = pd.read_excel(url)

#formatage des titres de colonnes
df_sharks.columns = pd.Series(df_sharks.columns).apply(lambda col: col.lower()) 
df_sharks.rename(columns= {'unnamed: 11': 'is_fatal'}, inplace=True)

#mofication des fonctions automatiques (via le fichier .py)
# %load_ext autoreload
# %autoreload 2 

df_sharks
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#              date    year        type    country              state  \
# 0     15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
# ...           ...     ...         ...        ...                ...
# 6964          NaN     NaN         NaN        NaN                NaN
# 6965          NaN     NaN         NaN        NaN                NaN
# 6966          NaN     NaN         NaN        NaN                NaN
# 6967          NaN     NaN         NaN        NaN                NaN
# 6968          NaN     NaN         NaN        NaN                NaN
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dd78f5ee-eaa3-4dc0-b230-d231fe730c56' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
